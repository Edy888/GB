# %%
### --- Jupyter Notebook --- ###


# python -m venv myenv
# source myenv/Scripts/activate
# pip install jupyter
# pip install jupyterlab
# 
#   git init
#   git checkout -b main
#   git remote add origin https://github.com/Edy888/python_prj.git / change remote: git remote set-url origin https://github.com/Edy888/python_prj.git
#   git add . / git commit -m "Initial commit"
#   git push -u origin main / git push -u origin <имя_ветки>
#   git pull origin master   / git pull origin main --allow-unrelated-histories

# 1. Создайте новый проект: В меню выберите "Файл" -> "Открыть папку" и выберите или создайте новую папку для вашего проекта.

# 2. Создайте виртуальное окружение (опционально): Если вы хотите использовать виртуальное окружение, выполните следующую команду в терминале: python -m venv myenv

#    Создание виртуального окружения с помощью команды python -m venv myenv позволяет изолировать зависимости вашего проекта 
#    от других проектов или системных пакетов Python. Вот что дает создание виртуального окружения:
#       A. Изоляция зависимостей: Каждый проект может иметь свое собственное виртуальное окружение, где будут установлены только те пакеты Python, 
#          которые требуются для этого конкретного проекта. Это предотвращает конфликты между версиями пакетов в разных проектах.
#       B. Чистота и портативность: Виртуальное окружение создает изолированную среду, которая содержит все необходимые зависимости проекта, 
#          не засоряя глобальное пространство Python на вашей системе. Это делает ваш проект более портативным и чистым.
#       C. Управление зависимостями: Вы можете легко управлять зависимостями вашего проекта с помощью инструмента управления пакетами Python, 
#          такого как pip. Вам не нужны специальные права администратора для установки пакетов в виртуальное окружение.
#       D. Воспроизводимость: Использование виртуального окружения обеспечивает воспроизводимость вашего проекта на других системах. Вы можете передать ваше виртуальное 
#          окружение вместе с кодом проекта, и другие пользователи смогут воспроизвести его без необходимости установки всех зависимостей вручную.
#       E. Изоляция от системных изменений: Виртуальное окружение не зависит от системных пакетов Python или их обновлений. 
#          Это позволяет вам экспериментировать с различными версиями пакетов без риска влияния на другие проекты или системные процессы.

# 3. Активируйте виртуальное окружение: Если вы создали виртуальное окружение, активируйте его: `source myenv/Scripts/activate`
# 4. Установите Jupyter Notebook: Выполните следующую команду в терминале для установки Jupyter Notebook: pip install jupyter
# 5. Запустите Jupyter Notebook: После установки введите следующую команду в терминале: jupyter notebook
# 6. Создайте новый блокнот: После запуска Jupyter Notebook в браузере откроется новая вкладка, где вы сможете создать новый блокнот. 
# Нажмите на кнопку "New" в верхнем правом углу и выберите "Python 3" или "Python [название вашего виртуального окружения]", чтобы создать новый блокнот.
#
# Чтобы правильно завершить работу с блокнотом в Jupyter Notebook, выполните следующие шаги: 
# 1. Сохранение блокнота: Убедитесь, что вы сохранили все изменения в блокноте. Вы можете сделать это, выбрав "Save and Checkpoint" в меню "File", 
# нажав на кнопку "Save" или используя комбинацию клавиш Ctrl+S.
# 2. Закрытие блокнота: Закройте вкладку или окно браузера, в котором открыт Jupyter Notebook, после того как вы закончили работу с блокнотом.
# 3. Остановка сервера Jupyter Notebook: Если вы запускали сервер Jupyter Notebook локально на вашем компьютере, не забудьте остановить его, чтобы освободить 
# ресурсы. В консоли, где вы запустили Jupyter Notebook, нажмите Ctrl+C, а затем подтвердите остановку, нажав y и Enter.
# 4. Этими шагами вы корректно завершите работу с блокнотом в Jupyter Notebook. Ваши изменения будут сохранены, и сервер Jupyter Notebook будет остановлен.

### --- JupyterLab --- ###

# Чтобы использовать JupyterLab, следуйте этим шагам:
# 1. Установка JupyterLab: Если у вас еще не установлен JupyterLab, выполните установку с помощью pip: pip install jupyterlab
# 2. Запуск JupyterLab: Запустите JupyterLab, введя следующую команду в терминале или командной строке: jupyter lab
# 3. Открытие блокнота: После запуска JupyterLab откроется веб-интерфейс в вашем браузере по умолчанию. 
# 4. В левой части экрана вы увидите файловую структуру вашей файловой системы. Щелкните по блокноту .ipynb, чтобы его открыть.
# 5. Использование JupyterLab: В JupyterLab вы можете работать с блокнотами, создавать новые, запускать код, добавлять 
# и редактировать ячейки, а также использовать различные расширения и функции для улучшения вашего опыта работы с данными и кодом.
# 6. Сохранение работы: Не забудьте сохранить свою работу, используя соответствующие кнопки в интерфейсе JupyterLab или клавиатурные комбинации, такие как Ctrl+S для быстрого сохранения.
# 7. Завершение работы: После завершения работы с JupyterLab закройте веб-интерфейс в браузере и остановите сервер JupyterLab, нажав Ctrl+C в терминале или командной строке, где запущен JupyterLab.

### ---Отправка проекта в GIT--- ########

# 1. Инициализация Git репозитория:
#    Откройте терминал или командную строку в корневой папке вашего проекта.
#    Запустите команду git init для инициализации нового Git репозитория в этой папке.
# 2. Добавление файлов в репозиторий:
#    Используйте команду git add ., чтобы добавить все файлы и папки вашего проекта в индекс Git. 
#    Если вы хотите добавить только определенные файлы, замените . на их имена.
# 3. Фиксация изменений:
#    Выполните команду git commit -m "Initial commit", чтобы зафиксировать добавленные файлы в репозиторий. 
#    Вместо "Initial commit" вы можете написать любое сообщение, описывающее ваши изменения.
# 4. Настройка удаленного репозитория:
#    Зайдите на ваш хостинг Git (например, GitHub, GitLab, Bitbucket) и создайте новый репозиторий.
#    Скопируйте URL удаленного репозитория. Например, для GitHub URL будет выглядеть как https://github.com/username/repository.git.
# 5. Связывание с удаленным репозиторием:
#    Вернитесь в терминал или командную строку и выполните команду git remote add origin <URL>, где <URL> - это URL вашего удаленного репозитория.
# 6. Отправка изменений на удаленный репозиторий:
#    Используйте команду git push -u origin master, чтобы отправить ваши изменения на удаленный репозиторий. 
#    Это также устанавливает отслеживание между вашим локальным мастер-веткой и веткой на удаленном репозитории.

### --- Global update PIP --- ###

# 1. Чтобы выйти из виртуального окружения и перейти в глобальное окружение Python для обновления pip, 
#       вы можете использовать команду деактивации для вашей оболочки. bash : deactivate
# 2. После выхода из виртуального окружения вы сможете использовать команду python -m pip install --upgrade pip 
#       для обновления pip в глобальном окружении.
# 3. Чтобы вернуться в ваше виртуальное окружение проекта после того, как вы вышли из него, вы должны снова активировать его. 
#       bash : source myenv/Scripts/activate
#       После выполнения этой команды вы снова активируете ваше виртуальное окружение, и вы будете работать в контексте этого окружения проекта.

### --- Check pip / Python version --- ###

# $ pip --version
# pip 24.0 from C:\Users\user\Desktop\Learning DS\2. Python\1. Python_jupyter\myenv\Lib\site-packages\pip (python 3.11)
# (myenv) 

# $ python --version
# Python 3.11.5
# (myenv)

### --- Чтобы обновить версию Python в вашем виртуальном окружении --- ###

# Чтобы обновить версию Python в вашем виртуальном окружении
#
#   1. Установите новую версию Python на вашем компьютере, если еще не установили.
#       A. Загрузите установщик Python: Перейдите на официальный сайт Python (https://www.python.org/downloads/) 
#          и загрузите установщик для соответствующей версии вашей операционной системы (Windows, macOS, Linux).
#       B. Запустите установщик: Запустите загруженный установщик Python и следуйте инструкциям на экране. 
#          Убедитесь, что выбрана опция добавления Python в PATH (если это возможно), чтобы иметь доступ к Python из любой директории через командную строку.
#       C. Выберите установочные параметры: При установке убедитесь, что вы выбираете опции, которые соответствуют вашим потребностям, например, 
#          установку pip (менеджера пакетов Python) и добавление Python в переменные среды.
#       D. Завершите установку: Дождитесь завершения установки Python. После завершения установки вы можете проверить версию Python, 
#          запустив команду python --version в командной строке или терминале.
#
#   2. Создайте новое виртуальное окружение с использованием новой версии Python. 
#       Например, если вы установили Python версии 3.12 и хотите создать виртуальное окружение с именем myenv_new, выполните следующую команду:
#       python3.12 -m venv myenv_new . Это создаст новое виртуальное окружение myenv_new с использованием Python версии 3.12. 
#       Переместите его на первое место в PATH
#   3. Активируйте новое виртуальное окружение: На Windows: myenv_new\Scripts\activate
#   4. Установите необходимые пакеты и зависимости в новом виртуальном окружении с помощью pip.
#   5. После того как вы убедитесь, что все работает как ожидается в новом окружении, 
#       вы можете удалить старое виртуальное окружение, если это необходимо, чтобы освободить место на диске.
#
### --- Add git remote --- ###

# Привязка вашего локального репозитория Git к удаленному репозиторию на GitHub включает в себя несколько шагов. Давайте разберем их по порядку:
#
#   1. Создание репозитория на GitHub: (например, "Python_projects")
#   2. Инициализация локального репозитория:
#       Инициализируйте локальный репозиторий Git с помощью команды git init.
#   3. git checkout main
#   3. Добавление удаленного репозитория: Скопируйте URL вашего репозитория на GitHub. 
#       В терминале выполните команду git remote add origin URL, где URL - это URL вашего репозитория на GitHub. Например:
#   4. Добавление файлов и выполнение коммита: git add . / git commit -m "Initial commit".
#   5. Отправка изменений на удаленный репозиторий:
#   6. Отправьте изменения на удаленный репозиторий с помощью команды git push -u origin main / git push -u origin <имя_ветки>

#   git init
#   git checkout -b main
#   git remote add origin https://github.com/Edy888/Python_projects.git 
#   git add . / git commit -m "Initial commit"
#   git push -u origin main / git push -u origin <имя_ветки>
#   git pull origin master 


### --- один цикл работы с проектом, начиная с изменений в локальном репозитории и завершая отправкой изменений на удаленный репозиторий на GitHub: --- ###

# 1. Внесение изменений в проект:
# 2. Добавление изменений в индекс Git: Добавьте измененные файлы в индекс Git с помощью команды git add .
# 3. Коммит изменений: Закоммитьте добавленные файлы с помощью команды git commit -m "Описание изменений". 
#       Вместо "Описание изменений" укажите краткое описание внесенных изменений.
# 4. Получение изменений из удаленного репозитория (необязательно): Если другие участники команды внесли изменения в удаленный репозиторий, 
#       вы можете получить их изменения с помощью команды git pull origin master. Это обновит ваш локальный репозиторий до последней версии из удаленного репозитория.
# 5. Отправка изменений на удаленный репозиторий: Отправьте ваши локальные изменения на удаленный репозиторий с помощью команды git push origin master.
#       После выполнения этих шагов ваши локальные изменения будут отправлены на удаленный репозиторий на GitHub. 
#       Если другие участники команды также работают с этим репозиторием, убедитесь, что вы получили их изменения перед отправкой своих собственных.
